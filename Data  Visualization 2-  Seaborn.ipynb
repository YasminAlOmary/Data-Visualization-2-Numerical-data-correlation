# %% [markdown]
# ## Data  Visualization 2
# ### Numerical data correlation
# ### Seaborn

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
df=sns.load_dataset('tips') 
num=df._get_numeric_data()

# %%
num
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
# to find correlation between data (positive -Negative )
num.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.regplot(df['tip'],df['total_bill'])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %%
# fit_reg=False to remove the line in chart
sns.regplot(df['tip'],df['total_bill'],fit_reg=False)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %%
# scatter_kws={'alpha':0.3} to appear the transparency and density of the data
sns.regplot(df['tip'],df['total_bill'],fit_reg=False ,scatter_kws={'alpha':0.3})
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %%
sns.regplot(df['tip'],df['total_bill'],fit_reg=False ,scatter_kws={'alpha':0.7})
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %%
#lmplot to plot data and draw regression model
#hue='gender'to appear the distribution of gender 
df.rename(columns={'sex':'gender'},inplace=True) 
sns.lmplot(x='tip',y='total_bill',data=df ,fit_reg=False ,scatter_kws={'alpha':0.15} ,hue='gender')

# %%
# plt.title:  to added title to the chart
sns.lmplot(x='tip',y='total_bill',data=df ,fit_reg=False ,scatter_kws={'alpha':0.15} ,hue='gender')   
plt.title ('tip and Total bill relation ')
# Out:
# Text(0.5, 1.0, 'tip and Total bill relation ')

# %%
# plt.axvline : to draw mean of tips with color red in chart.
sns.lmplot(x='tip',y='total_bill',data=df ,fit_reg=False ,scatter_kws={'alpha':0.15} ,hue='gender')   
plt.title ('tip and Total bill relation ')
plt.axvline(df['tip'].mean(),c='r')

# %%
sns.lmplot(x='tip',y='total_bill',data=df ,fit_reg=False ,scatter_kws={'alpha':0.15} ,hue='gender')   
plt.title ('tip and Total bill relation ')
plt.axvline(df['tip'].mean(),c='b')

# %%
# sns.jointplot: to appear  peak and frequency of the distribution  
sns.jointplot(df['tip'],df['total_bill'],kind='kde')
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# stats.pearsonr : to find correlation and  probability between the two column
stats.pearsonr(df['tip'],df['total_bill'])
# Out:
# (0.6757341092113642, 6.6924706468640476e-34)

# %%
stats.pearsonr(df['tip'],df['size'])
# Out:
# (0.489298775230357, 4.3005433272249695e-16)

# %%
# annotate(stats.pearsonr): to draw pearsonr
sns.jointplot(df['tip'],df['total_bill'],kind='kde').annotate(stats.pearsonr)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-e34aeb2facaa> in <module>
# ----> 1 sns.jointplot(df['tip'],df['total_bill'],kind='kde').annotate(stats.pearsonr)
#
# AttributeError: 'JointGrid' object has no attribute 'annotate'

# %%
# FacetGrid : to view grouped between two  data
plt.figure(figsize=(15,10))
sns.FacetGrid (df, col='gender',row='smoker' ).map(sns.regplot,'tip','total_bill')

# %%
plt.figure(figsize=(15,10))
sns.FacetGrid (df, col='day',row='smoker' ).map(sns.regplot,'tip','total_bill')

# %%
plt.figure(figsize=(15,10))
sns.FacetGrid (df, col='day',row='smoker' ).map(sns.regplot,'tip','size')

# %%
plt.figure(figsize=(15,10))
sns.FacetGrid (df, col='gender',row='smoker' ).map(sns.boxplot,'tip')
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\axisgrid.py:645: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
#tip and day grouped by box plot
plt.figure(figsize=(15,10))
sns.FacetGrid (df, col='gender',row='smoker' ).map(sns.boxplot,'day','tip')
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\axisgrid.py:645: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
df['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
# divided data in 4 category include min and max .
x=np.linspace(df['total_bill'].min(),df['total_bill'].max(),4)
x
# Out:
# array([ 3.07      , 18.98333333, 34.89666667, 50.81      ])

# %%
cluster=pd.cut(df['total_bill'],x,labels=['eco','med','high'])
cluster
# Out:
# 0      eco
# 1      eco
# 2      med
# 3      med
# 4      med
#       ...
# 239    med
# 240    med
# 241    med
# 242    eco
# 243    eco
# Name: total_bill, Length: 244, dtype: category
# Categories (3, object): ['eco' < 'med' < 'high']

# %%
cluster.value_counts ()
# Out:
# eco     139
# med      88
# high     16
# Name: total_bill, dtype: int64

# %%
cluster.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#to show numerical data as a categorical 
sns.boxplot(cluster,df['total_bill'])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill', ylabel='total_bill'>

# %%
sns.boxplot(cluster,df['size'])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill', ylabel='size'>

# %%
sns.boxplot(cluster,df['tip'])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>
